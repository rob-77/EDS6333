# %% [markdown]
# ### A quality inspector checks a single motherboard from a production line. The historical defect rate is 5%. Let "finding a defect" be a Success (p=0.05). What is the probability the board is defective, and what is the variance of this distribution?

# %% [markdown]
# For a single motherboard with a historical defect rate of 5%, the number of defects follows a Bernoulli distribution with parameter .
# The probability the board is defective is simply , and the variance is .
#
# 📌 Key results
# - 	Probability(board is defective):
# -	Variance:

# %%
p = 0.05  # probability of defect (success)

prob_defective = p
variance = p * (1 - p)

print(f"Probability defective = {prob_defective:.4f}")
print(f"Variance = {variance:.4f}")
# Out:
# Probability defective = 0.0500
# Variance = 0.0475
